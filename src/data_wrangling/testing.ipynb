# %%
from load_data import load_political_quotes 
for batch in load_political_quotes(country=['United States of America'], political_alignment=['right-wing']):
    print('speaker:', batch.loc[batch.index[0], 'speaker'], ', quotation:', batch.loc[batch.index[0], 'quotation'])
# Out:
# ../../data/politician_quotes_dataset/quotes-2015-politicians.csv.gz
# speaker: Jerome Powell , quotation: a little more proof than usual
# speaker: Doc Hastings , quotation: They've given me a great honor and I just want to thank everybody for the support that I've had in the last 20 years. It's very meaningful to me,
# speaker: John Jagler , quotation: I'm not saying there isn't a place for remedial education,
# speaker: John Kasich , quotation: We need everything; we need oil, we need gas, we need clean coal, we need renewables,
# speaker: Brian Sullivan , quotation: The (city) budgetary process prioritizes and allocates investments in education, basic city services, economic development, assistance to our seniors, veterans and related social services among others,
# speaker: John Kasich , quotation: I wouldn't ever be one to tell you that I don't change my mind or that my thinking doesn't evolve.
# ...
